# %%
from luwiji.neural_network import illustration

# %% [markdown]
# # Mini batch
#
# Training a large data (especially images) is heavy!<br>
# We may not have enough resources to handle that much of data.<br>
# So what we'll do is to train them in batches that we called minibatch<br>

# %%
illustration.minibatch

# %%
illustration.minibatch_training
