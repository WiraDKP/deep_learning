# %%
from luwiji.rnn import illustration

# %% [markdown]
# # Watch this video, then proceed

# %% [markdown]
# https://www.youtube.com/watch?v=0E00Zuayv9Q

# %% [markdown]
# # Let's start with a question

# %%
illustration.i_have_a_pen

# %% [markdown]
# ### answer

# %%
illustration.i_have_an_apple

# %% [markdown]
# # Intuition behind LSTM (Long-Short Term Memory)

# %%
illustration.lstm

# %% [markdown]
# - FORGET: LTM * forget_factor
# - LEARN: STM + input
# - REMEMBER: not FORGET + LEARN -> new LTM
# - USE: not FORGET + LEARN -> prediction & new STM

# %% [markdown]
# # How it really looks like

# %%
illustration.lstm_math

# %% [markdown]
# # More detail about LSTM here

# %% [markdown]
# http://colah.github.io/posts/2015-08-Understanding-LSTMs/

# %% [markdown]
# # Gated Recurrent Unit (GRU)

# %% [markdown]
# Hanya 2 gate: UPDATE, RESET

# %%
illustration.gru

# %% [markdown]
# https://towardsdatascience.com/understanding-gru-networks-2ef37df6c9be

# %% [markdown]
# # Visualized

# %% [markdown]
# https://towardsdatascience.com/illustrated-guide-to-lstms-and-gru-s-a-step-by-step-explanation-44e9eb85bf21
